# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Data_train_reduced.csv')

# %%
data
# Out:
#       Respondent.ID  ...  s13b.bottles.of.Deodorant.do.you.currently.own
# 0              3800  ...                                               3
# 1              3801  ...                                               4
# 2              3802  ...                                               2
# 3              3803  ...                                               3
# 4              3804  ...                                               3
# 5              3805  ...                                               2
# 6              3806  ...                                               5
# 7              3807  ...                                               3
# 8              3808  ...                                               4
# 9              3809  ...                                               2
# 10             3810  ...                                               3
# 11             3811  ...                                               5
# ...

# %%
data['Product'].value_counts()
# Out:
# Deodorant H    500
# Deodorant F    500
# Deodorant B    500
# Deodorant J    500
# Deodorant G    500
# Name: Product, dtype: int64

# %%
train_y = data['Instant.Liking']

# %%
# Out:
#       q1_1.personal.opinion.of.this.Deodorant  ...  s13b.bottles.of.Deodorant.do.you.currently.own
# 0                                           4  ...                                               3
# 1                                           5  ...                                               4
# 2                                           6  ...                                               2
# 3                                           4  ...                                               3
# 4                                           4  ...                                               3
# 5                                           5  ...                                               2
# 6                                           7  ...                                               5
# 7                                           5  ...                                               3
# ...

# %%
for i in data.columns[4:]:
  data[i].fillna(data[i].median(skipna = True), inplace = True)

# %%
data.isnull().sum()
# Out:
# Respondent.ID                                              0
# Product.ID                                                 0
# Product                                                    0
# Instant.Liking                                             0
# q1_1.personal.opinion.of.this.Deodorant                    0
# q2_all.words                                               0
# q3_1.strength.of.the.Deodorant                             0
# q4_1.artificial.chemical                                   0
# q4_2.attractive                                            0
# q4_3.bold                                                  0
# q4_4.boring                                                0
# q4_5.casual                                                0
# q4_6.cheap                                                 0
# q4_7.clean                                                 0
# q4_8.easy.to.wear                                          0
# ...

# %%
train_X = data[data.columns[4:]]
train_X
# Out:
#       q1_1.personal.opinion.of.this.Deodorant  ...  s13b.bottles.of.Deodorant.do.you.currently.own
# 0                                           4  ...                                               3
# 1                                           5  ...                                               4
# 2                                           6  ...                                               2
# 3                                           4  ...                                               3
# 4                                           4  ...                                               3
# 5                                           5  ...                                               2
# 6                                           7  ...                                               5
# 7                                           5  ...                                               3
# ...

# %%
from sklearn.linear_model import LogisticRegression

# %%
model2 = LogisticRegression(solver='lbfgs')
model = LogisticRegression()

# %%
model2.fit(train_X,train_y)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
model.fit(train_X,train_y)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
test_data = pd.read_csv('test_data.csv')

# %%
for i in test_data.columns[4:]:
  test_data[i].fillna(test_data[i].median(skipna = True), inplace = True)

# %%
test_data['q1_1.personal.opinion.of.this.Deodorant']
# Out:
# 0       7
# 1       6
# 2       6
# 3       5
# 4       6
# 5       7
# 6       5
# 7       6
# 8       5
# 9       5
# 10      6
# 11      6
# 12      6
# 13      5
# 14      3
# 15      6
# 16      6
# 17      7
# 18      6
# 19      6
# 20      7
# 21      4
# 22      2
# 23      5
# 24      6
# 25      6
# 26      5
# 27      4
# 28      6
# 29      6
#        ..
# 5075    7
# 5076    5
# 5077    1
# 5078    5
# 5079    2
# 5080    1
# 5081    5
# 5082    6
# 5083    6
# 5084    5
# 5085    5
# 5086    1
# 5087    6
# 5088    7
# 5089    1
# 5090    7
# 5091    3
# 5092    4
# 5093    6
# 5094    5
# 5095    6
# 5096    5
# 5097    5
# 5098    5
# 5099    2
# 5100    6
# 5101    3
# 5102    4
# 5103    5
# 5104    6
# Name: q1_1.personal.opinion.of.this.Deodorant, Length: 5105, dtype: int64

# %%
test_X = data[data.columns[4:]]

# %%
test_y = data['Instant.Liking']

# %%
pred1 = model.predict(test_X)

# %%
from sklearn.metrics import mean_absolute_error

# %%
print(mean_absolute_error(pred1,test_y))
# Out:
# 0.0

# %%
print(mean_absolute_error(model2.predict(test_X),test_y))
# Out:
# 0.0

# %%
pred1
# Out:
# array([1, 0, 0, ..., 1, 0, 0])

# %%
test_y
# Out:
# 0       1
# 1       0
# 2       0
# 3       1
# 4       1
# 5       0
# 6       0
# 7       0
# 8       0
# 9       1
# 10      0
# 11      0
# 12      0
# 13      1
# 14      1
# 15      0
# 16      0
# 17      1
# 18      0
# 19      0
# 20      0
# 21      0
# 22      1
# 23      0
# 24      0
# 25      1
# 26      0
# 27      0
# 28      0
# 29      0
#        ..
# 2470    0
# 2471    0
# 2472    0
# 2473    0
# 2474    0
# 2475    0
# 2476    1
# 2477    0
# 2478    0
# 2479    0
# 2480    0
# 2481    0
# 2482    0
# 2483    1
# 2484    0
# 2485    0
# 2486    0
# 2487    0
# 2488    0
# 2489    1
# 2490    0
# 2491    1
# 2492    1
# 2493    0
# 2494    1
# 2495    0
# 2496    0
# 2497    1
# 2498    0
# 2499    0
# Name: Instant.Liking, Length: 2500, dtype: int64
